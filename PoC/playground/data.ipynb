# %%
# PC-KEIBA 接続は search1_race_result/work/db.py と共通。
# EQUISCOUT_PG_URL または work/.db_url を使う。
import sys
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
if ROOT.name == "playground":
    WORK = ROOT / "contrail_offspring" / "search1_race_result" / "work"
else:
    WORK = ROOT / "playground" / "contrail_offspring" / "search1_race_result" / "work"
sys.path.insert(0, str(WORK))

from db import get_engine

engine = get_engine()
